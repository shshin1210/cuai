# %%
import pandas as pd

# %%
naver_notfin = pd.read_csv('C:/Users/queenSSH/Desktop/학교/CUAI/cuai하계/네이버_웹툰_연재.csv', encoding= 'cp949')

# %%
naver_fin = pd.read_csv('C:/Users/queenSSH/crawl/네이버_웹툰_완결3.csv', encoding ='cp949')

# %%
for column in naver_notfin:
    print(column)
# Out:
# Unnamed: 0
# id
# title
# author
# day
# genre
# story
# platform
# age
# free
# complete
# thumbnail
# web
# rate

# %%
for column in naver_fin:
    print(column)
# Out:
# Unnamed: 0
# id
# title
# author
# genre
# story
# platform
# age
# complete
# thumbnail
# web
# rate
# free

# %%
naver_fin = naver_fin.drop('Unnamed: 0', axis = 1)

# %%
naver_fin.head()
# Out:
#    id   title author     genre  \
# 0   0  마물전담부대     염손  스토리, 판타지
# 1   1      불릿    김도근  스토리, 스포츠
# 2   2       더    공현곤  스토리, 스릴러
# 3   3     각자의     오묘  스토리, 로맨스
# 4   4     노선도     효기  스토리, 스릴러
#
#                                                story platform  age  complete  \
# 0  마법혁명으로 근대화를 이룬 판타지 세계.\n하지만 이러한 세계에서도 마물은 여전히 ...   네이버 웹툰    0         1
# 1  축구부 에이스, 좋아하는 선배에게 고백하려 했는데... 에어소프트 게임 마스터가 된다?!   네이버 웹툰    0         1
# 2  수천년 전 조상들의 경주로 정해진 12인의 운명. 자리를 지키려는 1등과 바꾸려는 ...   네이버 웹툰   15         1
# 3             헤어졌지만 헤어지지 않은 사이\n솔직하지 못한 우리들 어떻게 될까요?   네이버 웹툰    0         1
# 4  암호화폐 투자 실패로 모든 걸 잃은 평범한 40대 회사원 '권한수'.\n절망한 그의...   네이버 웹툰   15         1
#
#                                            thumbnail  \
# 0  https://shared-comic.pstatic.net/thumb/webtoon...
# 1  https://shared-comic.pstatic.net/thumb/webtoon...
# 2  https://shared-comic.pstatic.net/thumb/webtoon...
# 3  https://shared-comic.pstatic.net/thumb/webtoon...
# ...

# %%
naver_notfin = naver_notfin.drop(['Unnamed: 0'], axis =1)

# %%
naver_notfin.head()
# Out:
#    id    title     author day     genre  \
# 0   0     신의 탑        SIU   월  스토리, 판타지
# 1   1      참교육  채용택 / 한가람   월   스토리, 액션
# 2   2  뷰티풀 군바리   설이 / 윤성원   월  스토리, 드라마
# 3   3   윈드브레이커        조용석   월  스토리, 스포츠
# 4   4     백수세끼         치즈   월  스토리, 드라마
#
#                                                story platform  age  free  \
# 0    자신의 모든 것이었던 소녀를 쫓아 탑에 들어온 소년\n그리고 그런 소년을 시험하는 탑   네이버 웹툰   12     1
# 1  무너진 교권을 지키기 위해 교권보호국 소속 나화진의 참교육이 시작된다!\n&lt;부...   네이버 웹툰   15     1
# 2                      여자도 군대에 간다면?'본격 여자도 군대 가는 만화!   네이버 웹툰   15     1
# 3  혼자서 자전거를 즐겨타던 모범생 조자현.\n원치 않게 자전거 크루의 일에 자꾸 휘말...   네이버 웹툰   12     1
# 4  백수 시절 내 곁을 지켜줬던 그녀... 돌아와 주면 안 되겠니?\n음식 메뉴마다 담...   네이버 웹툰    0     1
#
#    complete                                          thumbnail  \
# 0         0  https://shared-comic.pstatic.net/thumb/webtoon...
# 1         0  https://shared-comic.pstatic.net/thumb/webtoon...
# 2         0  https://shared-comic.pstatic.net/thumb/webtoon...
# ...

# %%
naver_fin['day'] = 0

# %%
naver_fin.head()
# Out:
#    id   title author     genre  \
# 0   0  마물전담부대     염손  스토리, 판타지
# 1   1      불릿    김도근  스토리, 스포츠
# 2   2       더    공현곤  스토리, 스릴러
# 3   3     각자의     오묘  스토리, 로맨스
# 4   4     노선도     효기  스토리, 스릴러
#
#                                                story platform  age  complete  \
# 0  마법혁명으로 근대화를 이룬 판타지 세계.\n하지만 이러한 세계에서도 마물은 여전히 ...   네이버 웹툰    0         1
# 1  축구부 에이스, 좋아하는 선배에게 고백하려 했는데... 에어소프트 게임 마스터가 된다?!   네이버 웹툰    0         1
# 2  수천년 전 조상들의 경주로 정해진 12인의 운명. 자리를 지키려는 1등과 바꾸려는 ...   네이버 웹툰   15         1
# 3             헤어졌지만 헤어지지 않은 사이\n솔직하지 못한 우리들 어떻게 될까요?   네이버 웹툰    0         1
# 4  암호화폐 투자 실패로 모든 걸 잃은 평범한 40대 회사원 '권한수'.\n절망한 그의...   네이버 웹툰   15         1
#
#                                            thumbnail  \
# 0  https://shared-comic.pstatic.net/thumb/webtoon...
# 1  https://shared-comic.pstatic.net/thumb/webtoon...
# 2  https://shared-comic.pstatic.net/thumb/webtoon...
# 3  https://shared-comic.pstatic.net/thumb/webtoon...
# ...

# %%
columns = naver_fin.columns.tolist()
print(columns)
# Out:
# ['id', 'title', 'author', 'genre', 'story', 'platform', 'age', 'complete', 'thumbnail', 'web', 'rate', 'free', 'day']

# %%
naver_fin = naver_fin[['id', 'title', 'author','day', 'genre','platform', 'story',  'age', 'rate','free','complete', 'thumbnail', 'web']]

# %%
naver_fin.head(0)
# Out:
# Empty DataFrame
# Columns: [id, title, author, day, genre, platform, story, age, rate, free, complete, thumbnail, web]
# Index: []

# %%
naver_notfin = naver_notfin[['id', 'title', 'author','day', 'genre','platform', 'story',  'age', 'rate','free','complete', 'thumbnail', 'web']]

# %%
naver_notfin.head(0)
# Out:
# Empty DataFrame
# Columns: [id, title, author, day, genre, platform, story, age, rate, free, complete, thumbnail, web]
# Index: []

# %%
naver_combined = pd.concat([naver_fin, naver_notfin], axis=0, ignore_index=True)

# %%
naver_combined.head(0)
# Out:
# Empty DataFrame
# Columns: [id, title, author, day, genre, platform, story, age, rate, free, complete, thumbnail, web]
# Index: []

# %%
naver_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1423 entries, 0 to 1422
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1423 non-null   int64
#  1   title      1423 non-null   object
#  2   author     1423 non-null   object
#  3   day        1423 non-null   object
#  4   genre      1423 non-null   object
#  5   platform   1423 non-null   object
#  6   story      1423 non-null   object
#  7   age        1423 non-null   int64
#  8   rate       1423 non-null   float64
#  9   free       1423 non-null   int64
#  10  complete   1423 non-null   int64
#  11  thumbnail  1423 non-null   object
#  12  web        1423 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 144.6+ KB

# %%
naver_combined.tail(10)
# Out:
#        id      title      author day     genre platform  \
# 1413  434    라커, 오프너    만취 / 바른꽃   일  스토리, 판타지   네이버 웹툰
# 1414  435  오늘 밤만 재워줘    해번 / 유나나   일  스토리, 로맨스   네이버 웹툰
# 1415  436      소녀 해미         이현우   일  스토리, 스릴러   네이버 웹툰
# 1416  437   위험한 신입사원  박수정 / Jiya   일  스토리, 로맨스   네이버 웹툰
# 1417  438     호수의 인어          박새   일  스토리, 로맨스   네이버 웹툰
# 1418  439         마도          이밤   일  스토리, 판타지   네이버 웹툰
# 1419  440       푸른불꽃           닺   일  스토리, 드라마   네이버 웹툰
# 1420  441        데이즈          양수   일  스토리, 스릴러   네이버 웹툰
# 1421  442      샤인 스타          김현   일  스토리, 로맨스   네이버 웹툰
# 1422  443       호시탐탐         박현정   일  스토리, 로맨스   네이버 웹툰
#
#                                                   story  age  rate  free  \
# 1413  무엇이든 '여는' 능력을 가진 김도빈 형사 앞에, 무엇이든 '잠가버리는' 범죄자 '...   15  9.93     1
# 1414  28살 모태솔로 감규리, 드디어 남자에게 '고백'을 받았는데... \n술에 취해 기...   12  9.78     1
# 1415  "난 당신을 지옥으로 보낼거야" 복수를 꿈꾸는 소녀 해미. 그녀는 천재적인 머리를 ...   15  9.73     1
# ...

# %%
naver_combined.to_csv('네이버_웹툰.csv')
